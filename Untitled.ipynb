# %%
from pycellid.core import CellData
from pycellid.core import CellsPloter
from pycellid.core2 import CellData as CellData2
import pandas as pd
import io
import numpy as np

# %%
df = CellData('samples_cellid')
df2 = CellData2('samples_cellid')

print("df", isinstance(df, CellData))
print("df2", isinstance(df2, CellData2))
# Out:
# df True
# df2 True

# %%
#repr
df
# Out:
#        pos  t_frame  cellID  time  f_local2_bg_cfp  f_local2_bg_rfp  \
# 0        1        0       0     0         372.9697         241.2194
# 1        1        1       0     0         377.4458         240.1235
# 3        1        3       0     0         391.3493         437.9252
# 4        1        4       0     0         367.9105         242.5352
# 18185    3       12     721     0         463.5887         250.3025
# 18186    3       12     722     0         509.0000         250.9851
# 18187    3       12     723     0         536.5789         251.0638
# 18188    3       12     724     0         460.7500         248.6575
#
#        f_local2_bg_tfp  f_local2_bg_yfp
# 0            12523.050         310.0760
# 1            12138.300         317.3976
# 3            11549.440         331.3429
# 4            11503.960         329.0977
# 18185        11368.400         571.9272
# 18186         9129.724         572.0000
# 18187        11238.870         423.4595
# ...

# %%
df2
# Out:
# CellData(data=0x7f25584f1550)

# %% [markdown]
# # CellData VS CellData2
#  ## CellDtata
#     --> Muestra el nombre del objeto.
#     --> La tabla se ven igua.
#     --> Ambos son instancias de CellData

# %%
repr(df)
# Out:
# '       pos  t_frame  cellID  time  f_local2_bg_cfp  f_local2_bg_rfp  \\\n0        1        0       0     0         372.9697         241.2194   \n1        1        1       0     0         377.4458         240.1235   \n3        1        3       0     0         391.3493         437.9252   \n4        1        4       0     0         367.9105         242.5352   \n18185    3       12     721     0         463.5887         250.3025   \n18186    3       12     722     0         509.0000         250.9851   \n18187    3       12     723     0         536.5789         251.0638   \n18188    3       12     724     0         460.7500         248.6575   \n\n       f_local2_bg_tfp  f_local2_bg_yfp  \n0            12523.050         310.0760  \n1            12138.300         317.3976  \n3            11549.440         331.3429  \n4            11503.960         329.0977  \n18185        11368.400         571.9272  \n18186         9129.724         572.0000  \n18187        11238.870         423.4595  \n18
# ...

# %%
repr(df2)
# Out:
# 'CellData(data=0x7f259854ba30)'

# %% [markdown]
# # repr
# **CellData Muestra tablas** -> Estilo Pandas
# **CellData Muestra id del objeto** -> Me gusta más pero no informa nada

# %%
df.fft_stat
# Out:
# 0        0.387982
# 1        0.443545
# 2        0.500724
# 3        0.591332
# 4        0.085026
#            ...
# 18184    0.556508
# 18185    0.040324
# 18186    0.672861
# 18187    0.494793
# 18188    0.827304
# Name: fft_stat, Length: 18189, dtype: float64

# %%
df2.fft_stat
# Out:
# 0        0.387982
# 1        0.443545
# 2        0.500724
# 3        0.591332
# 4        0.085026
#            ...
# 18184    0.556508
# 18185    0.040324
# 18186    0.672861
# 18187    0.494793
# 18188    0.827304
# Name: fft_stat, Length: 18189, dtype: float64

# %%
df["a_tot"]
# Out:
# 0        527.0
# 1        614.0
# 2        639.0
# 3        688.0
# 4        457.0
#          ...
# 18184    147.0
# 18185    391.0
# 18186    587.0
# 18187    119.0
# 18188    120.0
# Name: a_tot, Length: 18189, dtype: float64

# %%
df2["a_tot"]
# Out:
# 0        527.0
# 1        614.0
# 2        639.0
# 3        688.0
# 4        457.0
#          ...
# 18184    147.0
# 18185    391.0
# 18186    587.0
# 18187    119.0
# 18188    120.0
# Name: a_tot, Length: 18189, dtype: float64

# %%
print("df", isinstance(df, CellData))
print("df2", isinstance(df2, CellData2))
# Out:
# df True
# df2 True

# %%
print("df", isinstance(df.a_tot, CellData))
print("df2", isinstance(df2.a_tot, CellData2))
# Out:
# df False
# df2 False

# %%
df[df["a_tot"]<200]
# Out:
#        pos  t_frame          ucid  cellID  time  xpos  ypos  a_tot  num_pix  \
# 101      1       10  100000000030      30     0    93   725  125.0      125
# 102      1       11  100000000030      30     0    92   724  120.0      120
# 103      1       12  100000000030      30     0    91   724  117.0      117
# 116      1       12  100000000038      38     0  1371   333  141.0      141
# 149      1        6  100000000042      42     0   129  1000  107.0      107
# ...    ...      ...           ...     ...   ...   ...   ...    ...      ...
# 18180    3       12  300000000716     716     0   641   819  140.0      140
# 18182    3       12  300000000718     718     0   784   735  189.0      189
# 18184    3       12  300000000720     720     0   802   736  147.0      147
# 18187    3       12  300000000723     723     0   986   336  119.0      119
# 18188    3       12  300000000724     724     0  1014    84  120.0      120
#
# ...

# %%
df2[df2["a_tot"]<200]
# Out:
#        pos  t_frame          ucid  cellID  time  xpos  ypos  a_tot  num_pix  \
# 101      1       10  100000000030      30     0    93   725  125.0      125
# 102      1       11  100000000030      30     0    92   724  120.0      120
# 103      1       12  100000000030      30     0    91   724  117.0      117
# 116      1       12  100000000038      38     0  1371   333  141.0      141
# 149      1        6  100000000042      42     0   129  1000  107.0      107
# ...    ...      ...           ...     ...   ...   ...   ...    ...      ...
# 18180    3       12  300000000716     716     0   641   819  140.0      140
# 18182    3       12  300000000718     718     0   784   735  189.0      189
# 18184    3       12  300000000720     720     0   802   736  147.0      147
# 18187    3       12  300000000723     723     0   986   336  119.0      119
# 18188    3       12  300000000724     724     0  1014    84  120.0      120
#
# ...

# %%
print("df", isinstance(df[df["a_tot"]<200], CellData))
print("df2", isinstance(df2[df2["a_tot"]<200], CellData2))
# Out:
# df False
# df2 False

# %%
df.isin([500])
# Out:
#          pos  t_frame   ucid  cellID   time   xpos   ypos  a_tot  num_pix  \
# 0      False    False  False   False  False  False  False  False    False
# 1      False    False  False   False  False  False  False  False    False
# 2      False    False  False   False  False  False  False  False    False
# 3      False    False  False   False  False  False  False  False    False
# 4      False    False  False   False  False  False  False  False    False
# ...      ...      ...    ...     ...    ...    ...    ...    ...      ...
# 18184  False    False  False   False  False  False  False  False    False
# 18185  False    False  False   False  False  False  False  False    False
# 18186  False    False  False   False  False  False  False  False    False
# 18187  False    False  False   False  False  False  False  False    False
# 18188  False    False  False   False  False  False  False  False    False
#
#        fft_stat  ...  f_nucl_tag6_tfp  f_nucl_tag6_yfp  f_local_bg_cfp  \
# ...

# %%
df2.isin([500])
# Out:
#          pos  t_frame   ucid  cellID   time   xpos   ypos  a_tot  num_pix  \
# 0      False    False  False   False  False  False  False  False    False
# 1      False    False  False   False  False  False  False  False    False
# 2      False    False  False   False  False  False  False  False    False
# 3      False    False  False   False  False  False  False  False    False
# 4      False    False  False   False  False  False  False  False    False
# ...      ...      ...    ...     ...    ...    ...    ...    ...      ...
# 18184  False    False  False   False  False  False  False  False    False
# 18185  False    False  False   False  False  False  False  False    False
# 18186  False    False  False   False  False  False  False  False    False
# 18187  False    False  False   False  False  False  False  False    False
# 18188  False    False  False   False  False  False  False  False    False
#
#        fft_stat  ...  f_nucl_tag6_tfp  f_nucl_tag6_yfp  f_local_bg_cfp  \
# ...

# %%
print("df", isinstance(df, CellData))
print("df2", isinstance(df2, CellData2))
# Out:
# df True
# df2 True

# %%
dfC = df[df["a_tot"]<200].copy()

print('df' ,isinstance(df, CellData))
print('dfC' ,isinstance(dfC, CellData))

print()

df2C = df2[df2["a_tot"]<200].copy()

print('df2' ,isinstance(df2, CellData))
print('df2C' ,isinstance(df2C, CellData))
# Out:
# df True
# dfC False
#
# df2 False
# df2C False

# %%
df2["a_tot"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
isinstance(df, CellData)
# Out:
# True

# %%
df.plot.cells_image(array_img_kws={"n":100})
# Out:
# <AxesSubplot:>

# %%
if isinstance(df, pd.DataFrame) or \
    isinstance(df, pd.Series) or \
    isinstance(df, CellData):
    print("ok")
# Out:
# ok

# %%
df.to_csv
# Out:
# <bound method NDFrame.to_csv of    a
# 0  1
# 1  2
# 2  3>

# %%
w=pd.DataFrame([('parrot', 24.0, 'second'), ('lion', 80.5, 1), ('monkey', np.nan, None)],columns=('name', 'max_speed', 'rank'))

# %%
repr(w)
# Out:
# '     name  max_speed    rank\n0  parrot       24.0  second\n1    lion       80.5       1\n2  monkey        NaN    None'
